# %%
# !python companylistgetter.py
# Out:
# No I AGREE button found.
#
# 🔄 Extracting data from page 1...
# Extracted: Asia Amalgamated Holdings Corporation | AAA | Holding Firms | 55 | 347
# Extracted: Atok-Big Wedge Co., Inc. | AB | Mining and Oil | 19 | 181
# Extracted: AbaCore Capital Holdings, Inc. | ABA | Holding Firms | 174 | 173
# Extracted: Asiabest Group International Inc. | ABG | Holding Firms | 176 | 350
# Extracted: ABS-CBN Corporation | ABS | Services | 114 | 123
# Extracted: ABS-CBN Holdings Corporation | ABSP | Services | 15 | 259
# Extracted: Ayala Corporation | AC | Holding Firms | 57 | 180
# Extracted: Acesite (Phils.) Hotel Corporation | ACE | Services | 48 | 370
# Extracted: ACEN CORPORATION | ACEN | Industrial | 233 | 140
# Extracted: Alsons Consolidated Resources, Inc. | ACR | Industrial | 121 | 170
# Extracted: Aboitiz Equity Ventures, Inc. | AEV | Holding Firms | 16 | 183
# Extracted: Alliance Global Group, Inc. | AGI | Holding Firms | 212 | 179
# ...

# %%
# !python timeseriesdatagetter.py
# Out:
# Fetching data for: Asia Amalgamated Holdings Corporation | companyId: 55
# Status code: 200
# Data received!
#  Data saved for Asia Amalgamated Holdings Corporation!
#
# Fetching data for: Atok-Big Wedge Co., Inc. | companyId: 19
# Status code: 200
# Data received!
#  Data saved for Atok-Big Wedge Co., Inc.!
#
# Fetching data for: AbaCore Capital Holdings, Inc. | companyId: 174
# Status code: 200
# Data received!
#  Data saved for AbaCore Capital Holdings, Inc.!
#
# Fetching data for: Asiabest Group International Inc. | companyId: 176
# Status code: 200
# Data received!
#  Data saved for Asiabest Group International Inc.!
#
# Fetching data for: ABS-CBN Corporation | companyId: 114
# Status code: 200
# Data received!
#  Data saved for ABS-CBN Corporation!
#
# Fetching data for: ABS-CBN Holdings Corporation | companyId: 15
# Status code: 200
# Data received!
#  Data saved for ABS-CBN Holdings Corporation!
#
# Fetching data for: Ayala Corporation | companyId: 57
# Status code: 200
# ...
